# %%
# %pip install openpyxl
# !pip install statsmodels
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

dataset = {
    "Year": list(range(2000, 2026)),
    "S&P %change": [+12.10, +16.39, +23.31, +24.23, -19.44, +26.89, +16.26 ,+28.88, -6.24, +19.42, +9.54, -0.73, +11.39, +29.60, +13.41, -0.00, +12.78, +23.45, -38.49, +3.53, +13.62, +3.00, +8.99, +26.38, -23.37, -13.04],
    "AMZN %change": [+11.33, +5.21, +44.39, +80.88, -49.62, +2.38, +76.26,+23.03, +28.43, +55.96, +10.95, +117.78, -22.18, +58.96 ,+44.93, -3.83, +33.81, +162.32, -44.65, +134.77, -16.31, +6.46, -15.83, +178.56, +74.58, -30.47]
}

print(len(dataset["Year"]), len(dataset["S&P %change"]), len(dataset["AMZN %change"]))
df = pd.DataFrame(dataset)

X = df[["S&P %change"]]
Y = df["AMZN %change"]
X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
# 26 26 26
#                             OLS Regression Results
# ...
# Dep. Variable:           AMZN %change   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     4.472
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):             0.0450
# Time:                        01:24:49   Log-Likelihood:                -140.89
# No. Observations:                  26   AIC:                             285.8
# Df Residuals:                      24   BIC:                             288.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          25.3461     12.483      2.031      0.054      -0.417      51.109
# ...
