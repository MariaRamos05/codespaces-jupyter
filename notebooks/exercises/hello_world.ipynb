# %%
student_name = "María Fernanda Ramos V."

print("Hello, World!")
print("Welcome,", student_name)
print("Course: Algorithms and Data Analysis")
print("Today we are practicing Git collaborations.")
# Out:
# Hello, World!
# Welcome, María Fernanda Ramos V.
# Course: Algorithms and Data Analysis
# Today we are practicing Git collaborations.
