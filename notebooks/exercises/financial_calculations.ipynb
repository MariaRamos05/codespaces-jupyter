# %%
student_name = "Maria Fernanda Ramos V."
course = "Algorithms and Data Analysis)"
print(f"Hello, my name is {student_name} and I am bettering the financial calculations file.")
# Out:
# Hello, my name is Maria Fernanda Ramos V. and I am bettering the financial calculations file.

# %%
present_value_1 = 1000
interest_rate_1 = 0.05
periods_1 = 10
future_value_1 = present_value_1 * (1 + interest_rate_1) ** periods_1
print(f"The future value of ${present_value_1} after {periods_1} years at an interest rate of {interest_rate_1*100}%")
# Out:
# The future value of $1000 after 10 years at an interest rate of 5.0%

# %%
present_value_2 = 7500
interest_rate_2 = 0.065
periods_2 = 20
future_value_2 = present_value_2 * (1 + interest_rate_2) ** periods_2
print(f"The future value of ${present_value_2} after {periods_2} years at an interest rate of {interest_rate_2*100}%")
# Out:
# The future value of $7500 after 20 years at an interest rate of 6.5%

# %%
print("Scenario 1: If you invest $1000 at an interest rate of 5% for 10 years, the future value will be:", future_value_1)
print("Scenario 2: If you invest $7500 at an interest rate of 6.5% for 20 years, the future value will be:", future_value_2)
# Out:
# Scenario 1: If you invest $1000 at an interest rate of 5% for 10 years, the future value will be: 1628.894626777442
# Scenario 2: If you invest $7500 at an interest rate of 6.5% for 20 years, the future value will be: 26427.33797638406

# %%
print("Scenario 1 is better for short-term investments, while Scenario 2 is better for long-term investments.")
# Out:
# Scenario 1 is better for short-term investments, while Scenario 2 is better for long-term investments.

# %%
print("This concludes the financial calculations for the two scenarios.")
# Out:
# This concludes the financial calculations for the two scenarios.
