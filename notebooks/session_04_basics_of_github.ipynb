# %% [markdown]
# Explanations, paagraphs, etc.
# the ones that say code you add codes only

# %%
student_name = "Maria Fernanda Ramos V."
course = "Algorithms and Data Analysis)"
print(f"Hello, my name is {student_name} and I am taking the course {course}.")
# Out:
# Hello, my name is Maria Fernanda Ramos V. and I am taking the course Algorithms and Data Analysis).

# %%
present_value = 1000
interest_rate = 0.05
periods = 10
future_value = present_value * (1+ interest_rate) ** periods
print(f"The future value of ${present_value} after {periods} years at an interest rate of {interest_rate*100}%"
)
# Out:
# The future value of $1000 after 10 years at an interest rate of 5.0%
